# %%
# The specialized library FinRL provides a ready-to-use financial trading environment.
# FinRL provides several environments based on OpenAI Gym for different markets, such as Stock Trading, Forex, or Cryptocurrency.
# !pip install finrl
# !pip install gym
# !pip install stable-baselines3
# !pip install alpaca-trade-api
# !pip install exchange-calendars
# !pip install stockstats
# !pip install wrds
# !pip install yfinance
# !pip install matplotlib seaborn

# %%
import gym
import finrl
from stable_baselines3 import PPO
#from finrl.env import StockTradingEnv
from finrl.data_processor import DataProcessor

# Load and preprocess data
data_processor = DataProcessor()
df = data_processor.download_data("AAPL")  # Example for Apple stock

# Create environment
env = StockTradingEnv(df)

# Initialize PPO agent
model = PPO("MlpPolicy", env, verbose=1)

# Train the agent
model.learn(total_timesteps=10000)

# Save the trained model
model.save("ppo_trading_agent")

# Evaluate the agent
obs = env.reset()
for _ in range(len(df)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 5
#       3 from stable_baselines3 import PPO
#       4 #from finrl.env import StockTradingEnv
# ----> 5 from finrl.data_processor import DataProcessor
#       7 # Load and preprocess data
#       8 data_processor = DataProcessor()
#
# ModuleNotFoundError: No module named 'finrl.data_processor'
